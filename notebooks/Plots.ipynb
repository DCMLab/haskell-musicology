-- %%
import Musicology.Plotting.Charts
import Musicology.IO.MidiFile
import Graphics.Rendering.Chart.Drawing
import Graphics.Rendering.Chart.Easy as CE
import Data.Default.Class
:opt svg

-- %%
piecePfx = "/home/chfin/Uni/phd/data/csapp/mozart-piano-sonatas/midi-norep/sonata"
sonata x = piecePfx ++ x ++ ".mid"
pieceFn = sonata "15-1"

-- %%
barlen <- pieceBarlen pieceFn
notes <- fmap asSecs <$> midiLoadNotes pieceFn

-- %%
let prplot = plotPianoRoll $ PRPlot notes $ pianoRollStyle (head defaultColorSeq)
layout = layout_title .~ "test"
       $ layout_plots .~ [prplot]
       $ def
toRenderable layout
-- Out:
-- <interactive>:1:1: error:
--     • No instance for (Show (Renderable ())) arising from a use of ‘print’
--     • In a stmt of an interactive GHCi command: print it

-- %%
toRenderable $ CE.execEC $ do
  layout_title .= "My Piano Roll Plot"
  layout_y_axis .= 
  plot $ return prplot
